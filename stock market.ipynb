# %%
import yfinance as yf

# %%
sp500=yf.Ticker('CSE')

# %%
sp500=sp500.history(period='max')

# %%
sp500.tail()
# Out:
#                             Open   High    Low  Close    Volume  Dividends  \
# Date
# 2014-04-01 00:00:00-04:00  14.60  15.18  14.55  15.15   2125800        0.0
# 2014-04-02 00:00:00-04:00  15.00  15.43  15.00  15.43   2653800        0.0
# 2014-04-03 00:00:00-04:00  15.67  15.87  15.50  15.81   2389500        0.0
# 2014-04-04 00:00:00-04:00  15.82  15.88  15.44  15.58   1924800        0.0
# 2014-04-07 00:00:00-04:00  15.56  15.71  15.35  15.50  28387900        0.0
#
#                            Stock Splits  Capital Gains
# Date
# 2014-04-01 00:00:00-04:00           0.0            0.0
# 2014-04-02 00:00:00-04:00           0.0            0.0
# 2014-04-03 00:00:00-04:00           0.0            0.0
# 2014-04-04 00:00:00-04:00           0.0            0.0
# 2014-04-07 00:00:00-04:00           0.0            0.0

# %%
sp500.index
# Out:
# DatetimeIndex(['2003-08-07 00:00:00-04:00', '2003-08-08 00:00:00-04:00',
#                '2003-08-11 00:00:00-04:00', '2003-08-12 00:00:00-04:00',
#                '2003-08-13 00:00:00-04:00', '2003-08-14 00:00:00-04:00',
#                '2003-08-15 00:00:00-04:00', '2003-08-18 00:00:00-04:00',
#                '2003-08-19 00:00:00-04:00', '2003-08-20 00:00:00-04:00',
#                ...
#                '2014-03-25 00:00:00-04:00', '2014-03-26 00:00:00-04:00',
#                '2014-03-27 00:00:00-04:00', '2014-03-28 00:00:00-04:00',
#                '2014-03-31 00:00:00-04:00', '2014-04-01 00:00:00-04:00',
#                '2014-04-02 00:00:00-04:00', '2014-04-03 00:00:00-04:00',
#                '2014-04-04 00:00:00-04:00', '2014-04-07 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=2685, freq=None)

# %%
sp500.plot.line(y='Close',use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500['Dividends']
del sp500['Stock Splits']
del sp500['Capital Gains']

# %%
sp500.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2003-08-07 00:00:00-04:00  16.879999  18.240000  16.480000  18.160000
# 2003-08-08 00:00:00-04:00  18.400000  18.719999  17.400000  18.000000
# 2003-08-11 00:00:00-04:00  18.000000  18.080000  17.719999  17.719999
# 2003-08-12 00:00:00-04:00  17.770000  18.299999  17.600000  18.299999
# 2003-08-13 00:00:00-04:00  18.150000  18.160000  17.799999  18.000000
#
#                              Volume
# Date
# 2003-08-07 00:00:00-04:00  13420900
# 2003-08-08 00:00:00-04:00   1447500
# 2003-08-11 00:00:00-04:00    615200
# 2003-08-12 00:00:00-04:00    391400
# 2003-08-13 00:00:00-04:00    434400

# %%
sp500['Tommorrow']=sp500['Close'].shift(-1)

# %%
sp500.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2003-08-07 00:00:00-04:00  16.879999  18.240000  16.480000  18.160000
# 2003-08-08 00:00:00-04:00  18.400000  18.719999  17.400000  18.000000
# 2003-08-11 00:00:00-04:00  18.000000  18.080000  17.719999  17.719999
# 2003-08-12 00:00:00-04:00  17.770000  18.299999  17.600000  18.299999
# 2003-08-13 00:00:00-04:00  18.150000  18.160000  17.799999  18.000000
#
#                              Volume  Tommorrow
# Date
# 2003-08-07 00:00:00-04:00  13420900  18.000000
# 2003-08-08 00:00:00-04:00   1447500  17.719999
# 2003-08-11 00:00:00-04:00    615200  18.299999
# 2003-08-12 00:00:00-04:00    391400  18.000000
# 2003-08-13 00:00:00-04:00    434400  17.600000

# %%
sp500['Target']=(sp500['Tommorrow']>sp500['Close']).astype(int)

# %%
sp500.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2003-08-07 00:00:00-04:00  16.879999  18.240000  16.480000  18.160000
# 2003-08-08 00:00:00-04:00  18.400000  18.719999  17.400000  18.000000
# 2003-08-11 00:00:00-04:00  18.000000  18.080000  17.719999  17.719999
# 2003-08-12 00:00:00-04:00  17.770000  18.299999  17.600000  18.299999
# 2003-08-13 00:00:00-04:00  18.150000  18.160000  17.799999  18.000000
#
#                              Volume  Tommorrow  Target
# Date
# 2003-08-07 00:00:00-04:00  13420900  18.000000       0
# 2003-08-08 00:00:00-04:00   1447500  17.719999       0
# 2003-08-11 00:00:00-04:00    615200  18.299999       1
# 2003-08-12 00:00:00-04:00    391400  18.000000       0
# 2003-08-13 00:00:00-04:00    434400  17.600000       0

# %%
from sklearn.ensemble import RandomForestClassifier

model =RandomForestClassifier(n_estimators=100,min_samples_split=100,random_state=1)

train=sp500.iloc[:-100]
test=sp500.iloc[-100:]

predictors=['Close','Volume','Open','High','Low']
model.fit(train[predictors],train['Target'])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds=model.predict(test[predictors])

# %%
import pandas as pd
preds= pd.Series(preds,index=test.index)

# %%
preds
# Out:
# Date
# 2013-11-12 00:00:00-05:00    1
# 2013-11-13 00:00:00-05:00    1
# 2013-11-14 00:00:00-05:00    0
# 2013-11-15 00:00:00-05:00    1
# 2013-11-18 00:00:00-05:00    1
#                             ..
# 2014-04-01 00:00:00-04:00    0
# 2014-04-02 00:00:00-04:00    1
# 2014-04-03 00:00:00-04:00    0
# 2014-04-04 00:00:00-04:00    0
# 2014-04-07 00:00:00-04:00    1
# Length: 100, dtype: int64

# %%
precision_score(test['Target'],preds)
# Out:
# 0.5

# %%
combined= pd.concat([test['Target'],preds],axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train,test,predictors,model):
    model.fit(train[predictors],train['Target'])
    preds=model.predict(test[predictors])
    preds=pd.Series(preds,index=test.index,name='Predictions')
    combined= pd.concat([test['Target'],preds],axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []
    
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions=backtest(sp500,model,predictors)

# %%
predictions['Predictions'].value_counts()
# Out:
# Predictions
# 1    127
# 0     58
# Name: count, dtype: int64

# %%
precision_score(predictions['Target'],predictions['Predictions'])
# Out:
# 0.5118110236220472

# %%
predictions['Target'].value_counts()/predictions.shape[0]
# Out:
# Target
# 0    0.513514
# 1    0.486486
# Name: count, dtype: float64

# %%
horizons= [2,5,60,250,1000]
new_predictors=[]

for horizon in horizons:
    rolling_averages =sp500.rolling(horizon).mean()
    ratio_column=f'Close_Ratio_{horizon}'
    sp500[ratio_column]=sp500['Close'] / rolling_averages['Close']
    trend_column =f'Trend_{horizon}'
    sp500[trend_column]=sp500.shift(1).rolling(horizon).sum()['Target']

    new_predictors +=[ratio_column,trend_column]

# %%
sp500
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2003-08-07 00:00:00-04:00  16.879999  18.240000  16.480000  18.160000
# 2003-08-08 00:00:00-04:00  18.400000  18.719999  17.400000  18.000000
# 2003-08-11 00:00:00-04:00  18.000000  18.080000  17.719999  17.719999
# 2003-08-12 00:00:00-04:00  17.770000  18.299999  17.600000  18.299999
# 2003-08-13 00:00:00-04:00  18.150000  18.160000  17.799999  18.000000
# ...                              ...        ...        ...        ...
# 2014-04-01 00:00:00-04:00  14.600000  15.180000  14.550000  15.150000
# 2014-04-02 00:00:00-04:00  15.000000  15.430000  15.000000  15.430000
# 2014-04-03 00:00:00-04:00  15.670000  15.870000  15.500000  15.810000
# 2014-04-04 00:00:00-04:00  15.820000  15.880000  15.440000  15.580000
# 2014-04-07 00:00:00-04:00  15.560000  15.710000  15.350000  15.500000
#
#                              Volume  Tommorrow  Target  Close_Ratio_2  \
# Date
# 2003-08-07 00:00:00-04:00  13420900  18.000000       0            NaN
# 2003-08-08 00:00:00-04:00   1447500  17.719999       0       0.995575
# 2003-08-11 00:00:00-04:00    615200  18.299999       1       0.992161
# 2003-08-12 00:00:00-04:00    391400  18.000000       0       1.016102
# 2003-08-13 00:00:00-04:00    434400  17.600000       0       0.991736
# ...                             ...        ...     ...            ...
# 2014-04-01 00:00:00-04:00   2125800  15.430000       1       1.018830
# 2014-04-02 00:00:00-04:00   2653800  15.810000       1       1.009156
# 2014-04-03 00:00:00-04:00   2389500  15.580000       0       1.012164
# 2014-04-04 00:00:00-04:00   1924800  15.500000       0       0.992673
# 2014-04-07 00:00:00-04:00  28387900        NaN       0       0.997426
#
#                            Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 2003-08-07 00:00:00-04:00      NaN            NaN      NaN             NaN
# 2003-08-08 00:00:00-04:00      NaN            NaN      NaN             NaN
# 2003-08-11 00:00:00-04:00      0.0            NaN      NaN             NaN
# 2003-08-12 00:00:00-04:00      1.0            NaN      NaN             NaN
# 2003-08-13 00:00:00-04:00      1.0       0.998004      NaN             NaN
# ...                            ...            ...      ...             ...
# 2014-04-01 00:00:00-04:00      2.0       1.040951      3.0        1.055847
# 2014-04-02 00:00:00-04:00      2.0       1.048376      4.0        1.073690
# 2014-04-03 00:00:00-04:00      2.0       1.051057      5.0        1.098540
# 2014-04-04 00:00:00-04:00      1.0       1.017503      4.0        1.081381
# 2014-04-07 00:00:00-04:00      0.0       1.000387      3.0        1.074921
#
#                            Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 2003-08-07 00:00:00-04:00       NaN              NaN        NaN
# 2003-08-08 00:00:00-04:00       NaN              NaN        NaN
# 2003-08-11 00:00:00-04:00       NaN              NaN        NaN
# 2003-08-12 00:00:00-04:00       NaN              NaN        NaN
# 2003-08-13 00:00:00-04:00       NaN              NaN        NaN
# ...                             ...              ...        ...
# 2014-04-01 00:00:00-04:00      29.0         1.249946      130.0
# 2014-04-02 00:00:00-04:00      30.0         1.270461      131.0
# 2014-04-03 00:00:00-04:00      30.0         1.298981      131.0
# 2014-04-04 00:00:00-04:00      29.0         1.277435      131.0
# 2014-04-07 00:00:00-04:00      28.0         1.268313      130.0
#
#                            Close_Ratio_1000  Trend_1000
# Date
# 2003-08-07 00:00:00-04:00               NaN         NaN
# 2003-08-08 00:00:00-04:00               NaN         NaN
# 2003-08-11 00:00:00-04:00               NaN         NaN
# 2003-08-12 00:00:00-04:00               NaN         NaN
# 2003-08-13 00:00:00-04:00               NaN         NaN
# ...                                     ...         ...
# 2014-04-01 00:00:00-04:00          1.888006       505.0
# 2014-04-02 00:00:00-04:00          1.920628       506.0
# 2014-04-03 00:00:00-04:00          1.965584       506.0
# 2014-04-04 00:00:00-04:00          1.934738       506.0
# 2014-04-07 00:00:00-04:00          1.922524       506.0
#
# [2685 rows x 17 columns]

# %%
sp500.dropna()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2007-07-30 00:00:00-04:00  19.110001  19.850000  18.629999  19.469999
# 2007-07-31 00:00:00-04:00  19.600000  20.299999  18.950001  19.000000
# 2007-08-01 00:00:00-04:00  18.709999  20.129999  15.340000  19.070000
# 2007-08-02 00:00:00-04:00  19.670000  20.000000  18.780001  19.830000
# 2007-08-03 00:00:00-04:00  19.830000  20.000000  18.799999  18.910000
# ...                              ...        ...        ...        ...
# 2014-03-31 00:00:00-04:00  14.280000  14.590000  14.270000  14.590000
# 2014-04-01 00:00:00-04:00  14.600000  15.180000  14.550000  15.150000
# 2014-04-02 00:00:00-04:00  15.000000  15.430000  15.000000  15.430000
# 2014-04-03 00:00:00-04:00  15.670000  15.870000  15.500000  15.810000
# 2014-04-04 00:00:00-04:00  15.820000  15.880000  15.440000  15.580000
#
#                              Volume  Tommorrow  Target  Close_Ratio_2  \
# Date
# 2007-07-30 00:00:00-04:00   4036900  19.000000       0       0.998974
# 2007-07-31 00:00:00-04:00   4902900  19.070000       1       0.987783
# 2007-08-01 00:00:00-04:00  20272400  19.830000       1       1.001839
# 2007-08-02 00:00:00-04:00   7454600  18.910000       0       1.019537
# 2007-08-03 00:00:00-04:00   4053400  19.190001       1       0.976252
# ...                             ...        ...     ...            ...
# 2014-03-31 00:00:00-04:00   1340600  15.150000       1       1.012491
# 2014-04-01 00:00:00-04:00   2125800  15.430000       1       1.018830
# 2014-04-02 00:00:00-04:00   2653800  15.810000       1       1.009156
# 2014-04-03 00:00:00-04:00   2389500  15.580000       0       1.012164
# 2014-04-04 00:00:00-04:00   1924800  15.500000       0       0.992673
#
#                            Trend_2  Close_Ratio_5  Trend_5  Close_Ratio_60  \
# Date
# 2007-07-30 00:00:00-04:00      0.0       0.979869      1.0        0.791233
# 2007-07-31 00:00:00-04:00      0.0       0.966626      1.0        0.776170
# 2007-08-01 00:00:00-04:00      1.0       0.982281      1.0        0.783039
# 2007-08-02 00:00:00-04:00      2.0       1.023431      2.0        0.817940
# 2007-08-03 00:00:00-04:00      1.0       0.982032      2.0        0.784241
# ...                            ...            ...      ...             ...
# 2014-03-31 00:00:00-04:00      2.0       1.008851      2.0        1.018037
# 2014-04-01 00:00:00-04:00      2.0       1.040951      3.0        1.055847
# 2014-04-02 00:00:00-04:00      2.0       1.048376      4.0        1.073690
# 2014-04-03 00:00:00-04:00      2.0       1.051057      5.0        1.098540
# 2014-04-04 00:00:00-04:00      1.0       1.017503      4.0        1.081381
#
#                            Trend_60  Close_Ratio_250  Trend_250  \
# Date
# 2007-07-30 00:00:00-04:00      22.0         0.761253      128.0
# 2007-07-31 00:00:00-04:00      21.0         0.743393      128.0
# 2007-08-01 00:00:00-04:00      22.0         0.746678      128.0
# 2007-08-02 00:00:00-04:00      23.0         0.776979      128.0
# 2007-08-03 00:00:00-04:00      22.0         0.741567      127.0
# ...                             ...              ...        ...
# 2014-03-31 00:00:00-04:00      29.0         1.206080      130.0
# 2014-04-01 00:00:00-04:00      29.0         1.249946      130.0
# 2014-04-02 00:00:00-04:00      30.0         1.270461      131.0
# 2014-04-03 00:00:00-04:00      30.0         1.298981      131.0
# 2014-04-04 00:00:00-04:00      29.0         1.277435      131.0
#
#                            Close_Ratio_1000  Trend_1000
# Date
# 2007-07-30 00:00:00-04:00          0.851350       477.0
# 2007-07-31 00:00:00-04:00          0.830763       477.0
# 2007-08-01 00:00:00-04:00          0.833774       478.0
# 2007-08-02 00:00:00-04:00          0.866945       478.0
# 2007-08-03 00:00:00-04:00          0.826691       478.0
# ...                                     ...         ...
# 2014-03-31 00:00:00-04:00          1.820301       505.0
# 2014-04-01 00:00:00-04:00          1.888006       505.0
# 2014-04-02 00:00:00-04:00          1.920628       506.0
# 2014-04-03 00:00:00-04:00          1.965584       506.0
# 2014-04-04 00:00:00-04:00          1.934738       506.0
#
# [1684 rows x 17 columns]

# %%
model=RandomForestClassifier(n_estimators=200,min_samples_split=50, random_state=1)

# %%
def predict(train,test,predictors,model):
    model.fit(train[predictors],train['Target'])
    preds=model.predict_proba(test[predictors])[:,1]
    preds[preds>=.6]=1
    preds[preds<0.6]=0
    preds=pd.Series(preds,index=test.index,name='Predictions')
    combined= pd.concat([test['Target'],preds],axis=1)
    return combined

# %%
predictions=backtest(sp500,model,new_predictors)

# %%
predictions['Predictions'].value_counts()
# Out:
# Predictions
# 0.0    181
# 1.0      4
# Name: count, dtype: int64

# %%
precision_score(predictions['Target'],predictions['Predictions'])
# Out:
# 0.75
